# %% [markdown]
# # Forest Cover Type - Outlier detection
# ## Mahalanobis analysis

# %%
import numpy as np
import scipy.spatial.distance as distance
from skimage import io
import warnings

warnings.filterwarnings("ignore")

# %run ../util/load_data.py
# %run ../util/data_visualization.py

# %% [markdown]
# ##### Load data

# %%
data = load_data("../../Data")
train_data = data['train_data']
train_data.head()
# Out:
#    Id  Elevation  Aspect  Slope  Horizontal_Distance_To_Hydrology  \
# 0   1       2596      51      3                               258
# 1   2       2590      56      2                               212
# 2   3       2804     139      9                               268
# 3   4       2785     155     18                               242
# 4   5       2595      45      2                               153
#
#    Vertical_Distance_To_Hydrology  Horizontal_Distance_To_Roadways  \
# 0                               0                              510
# 1                              -6                              390
# 2                              65                             3180
# 3                             118                             3090
# 4                              -1                              391
#
#    Hillshade_9am  Hillshade_Noon  Hillshade_3pm  \
# 0            221             232            148
# 1            220             235            151
# 2            234             238            135
# 3            238             238            122
# 4            220             234            150
#
#    Horizontal_Distance_To_Fire_Points  Cover_Type  Soil_Type  Wilderness_Type
# 0                                6279           5          9                1
# 1                                6225           5          9                1
# 2                                6121           2          2                1
# 3                                6211           2          0                1
# 4                                6172           5          9                1

# %% [markdown]
# ##### Extract numerical columns

# %%
train_data = train_data[data['numerical_attributes']]
train_data.head()
# Out:
#    Aspect  Elevation  Hillshade_3pm  Hillshade_9am  Hillshade_Noon  \
# 0      51       2596            148            221             232
# 1      56       2590            151            220             235
# 2     139       2804            135            234             238
# 3     155       2785            122            238             238
# 4      45       2595            150            220             234
#
#    Horizontal_Distance_To_Fire_Points  Horizontal_Distance_To_Hydrology  \
# 0                                6279                               258
# 1                                6225                               212
# 2                                6121                               268
# 3                                6211                               242
# 4                                6172                               153
#
#    Horizontal_Distance_To_Roadways  Slope  Vertical_Distance_To_Hydrology
# 0                              510      3                               0
# 1                              390      2                              -6
# 2                             3180      9                              65
# 3                             3090     18                             118
# 4                              391      2                              -1

# %% [markdown]
# ##### Calculate Maholanobis distance for each train instance

# %%
covariance_matrix = train_data.cov()
covariance_matrix_inverse = pd.DataFrame(np.linalg.pinv(covariance_matrix.values), covariance_matrix.columns, covariance_matrix.index)

means = train_data.mean()
mean_normalized_data = train_data - means

mahalanobis_distances = []
mahalanobis_distances2 = []
for index, row in mean_normalized_data.iterrows():
    mahalanobis_distance = np.sqrt(row.dot(covariance_matrix_inverse).dot(row))
    mahalanobis_distances.append(np.array([index, mahalanobis_distance]))
mahalanobis_distances = np.array(mahalanobis_distances)

# %% [markdown]
# ##### Extract outliers (instances that are too far from the mean)

# %%
MEAN_THRESHOLD = 1.2

mean_distance = mahalanobis_distances[:,1].mean()
threshold = MEAN_THRESHOLD * mean_distance
outliers = mahalanobis_distances[mahalanobis_distances[:,1] > threshold]
outliers_ids = outliers[:,]
without_outliers_data = data['train_data'][~data['train_data']['Id'].isin(outliers[:,1])]
outliers_ids = outliers[:,0]

# %% [markdown]
# ##### Create new array of colors with outlier

# %%
copy_train_data = data['train_data'][data['numerical_attributes'] + data['target'] + ['Id']].copy()
color = [row[data['target'][0]] if row['Id'] not in outliers_ids else -10 for index,row in copy_train_data.iterrows()]

# %% [markdown]
# #### Vizualizations

# %%
pca_visualization(data['train_data'][data['numerical_attributes'] + data['target']], data['target'][0], color)
# Out:
# <ggplot: (190756820442)>

# %%
tsne_visualization(data['train_data'][data['numerical_attributes'] + data['target']], data['target'][0], color)
# Out:
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 15120 samples in 0.026s...
# [t-SNE] Computed neighbors for 15120 samples in 1.197s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 15120
# [t-SNE] Computed conditional probabilities for sample 2000 / 15120
# [t-SNE] Computed conditional probabilities for sample 3000 / 15120
# [t-SNE] Computed conditional probabilities for sample 4000 / 15120
# [t-SNE] Computed conditional probabilities for sample 5000 / 15120
# [t-SNE] Computed conditional probabilities for sample 6000 / 15120
# [t-SNE] Computed conditional probabilities for sample 7000 / 15120
# [t-SNE] Computed conditional probabilities for sample 8000 / 15120
# [t-SNE] Computed conditional probabilities for sample 9000 / 15120
# [t-SNE] Computed conditional probabilities for sample 10000 / 15120
# [t-SNE] Computed conditional probabilities for sample 11000 / 15120
# [t-SNE] Computed conditional probabilities for sample 12000 / 15120
# [t-SNE] Computed conditional probabilities for sample 13000 / 15120
# [t-SNE] Computed conditional probabilities for sample 14000 / 15120
# [t-SNE] Computed conditional probabilities for sample 15000 / 15120
# [t-SNE] Computed conditional probabilities for sample 15120 / 15120
# [t-SNE] Mean sigma: 44.059217
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 78.099419
# [t-SNE] KL divergence after 300 iterations: 2.949076
# <ggplot: (190757312411)>

# %%
umap_visualization(data['train_data'][data['numerical_attributes'] + data['target']], data['target'][0], color)
